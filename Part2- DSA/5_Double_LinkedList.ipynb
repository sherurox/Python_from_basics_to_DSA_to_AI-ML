# %%
class Node:
    def __init__(self, value):
        return 0

class LinkedList:
    def __init__(self, value):
        return 0

    def print(self,value):
        return 0

    def append(self, value):
        return 0
    
    def pop(self):
        return 0

    def prepend(self, value):
        return 0
    
    def popfirst(self):
        return 0

    def get(self,index,value):
        return 0

    def set_value(self,index,value):
        return 0

    def insert(self, index, value):
        return 0

    def remmove(self, index):
        return 0
    
    # no reverse possible

# %%
# In doble Linked List there are two pointers for one node, one pointing forward, one backward

class Node:
    def __init__(self,value):
        self.value= value
        self.next=next
        self.prev=None
'''
{
"value" = 7
"next" = none
"prev" = none
}
'''

class Doblelinkedlist:
    def __init__(self,value):
        new_node = Node(value)
        self.head=new_node
        self.tail=new_node
        self.length= 1
# Out:
# '\n\n{\n\n"value" = 7\n"next" = none\n"prev" = none\n}\n\n'

# %%
# Now we learn how to append on double Linked List 

def append(self,value):
    new_node=Node(value)
    if self.head is None:
        self.head=new_node
        self.tail=new_node
    else:
        self.tail.next=new_node
        self.tail=None
        new_node.prev=self.tail
        self.tail=new_node
    self.length += 1
    return True

# %%
# now we learn how to pop

def pop(self,value):
    if self.length == 0:
        return None
    temp= self.tail
    if self.length == 1:
        self.head=0
        self.tail=0
    else: 
        self.tail=self.tail.prev
        self.tail.next=None
        temp.prev=None
    self.length -= 1
    return temp

# %%
# Now we learn how to prepend 

def prepend(self,value):
    new_node= Node(value)
    if self.head is None:
        self.head=new_node
        self.tail=new_node
    else:
        new_node.next=self.head
        self.head.prev=new_node
        self.head=new_node
    self.length += 1 
    return True

# %%
# Now we learan how to popfirst 

def popfirst(self):
    if self.length==0:
        return None
    temp=self.head
    if self.length==1:
        self.head=None
        self.head=None
    else:
        self.head=self.head.next
        self.head.prev=None
        temp.next = None
    self.length -= 1
    return True

# %%
# now we learn how to get    **** can be same as Linked list but is more optimized

def get(self,index):
    if index<0 or index>=self.length:
        return None
    if index <= (self.length/2):
        for _ in range(index):
            temp=temp.next
    else:
        temp=self.tail
        for _ in range(self.length-1,index,-1):
            temp=temp.prev
    return temp

# %%
# now we learn how to set values *****exactly same as linked list***** 

def set(self,index,value):
    temp=self.get(index)
    if temp:
        temp.value=value
        return True
    return False

# %%
# now we learn how to insert


def insert(self,index,value):
    if index<0 or index>self.length:
        return False
    if index == self.length:
        return self.append(value)
    if index == 0:
        return self.prepend(value)
    new_node=Node(value)
    before= self.get(index-1)
    after = before.next

    new_node.prev=before 
    new_node.next=after
    before.next=new_node
    after.prev=new_node
    self.length += 1
    return True

# %%
# now we learn how to remove 

def remove(self,index):
    if index <0 or index>=self.length: # for index out of range
            return None  # not false its None
    if index == 0:
            return self.pop_first() # for index 0 
    if index == self.length - 1:
            return self.pop()   # for index at last
    temp=self.get(index)
    '''
    before= self.get(index-1)
    after = self.get(index+1)
    
    after.prev=before
    before.next=after 
    
    temp.next= None 
    temp.prev=None 
    '''
    #or 

    temp.next.prev=temp.prev   #after.prev=before
    temp.prev.next=temp.next   #before.next= after 
    temp.next= None 
    temp.prev=None

    self.length -=1 
    return temp

# %%
# everything we learnt:

class Node:
    def __init__(self, value): # T O(1)  S O(1)
        self.value = value
        self.next = None
        self.prev = None
        
class DoublyLinkedList:
    def __init__(self, value): # T O(1)  S O(1)
        new_node = Node(value)
        self.head = new_node
        self.tail = new_node
        self.length = 1

    def append(self, value): # T O(1)  S O(1)
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
        self.length += 1
        return True
            
    def pop(self): # T O(1)  S O(1)
        if self.length == 0:
            return None
        temp = self.tail
        if self.length == 1:
            self.head = None
            self.tail = None 
        else:       
            self.tail = self.tail.prev
            self.tail.next = None
            temp.prev = None
        self.length -= 1
        return temp

    def prepend(self, value): # T O(1)  S O(1)
        new_node = Node(value)
        if self.length == 0:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node
        self.length += 1
        return True

    def pop_first(self): # T O(1)  S O(1)
        if self.length == 0:
            return None
        temp = self.head
        if self.length == 1:
            self.head = None
            self.tail = None
        else:
            self.head = self.head.next
            self.head.prev = None
            temp.next = None      
        self.length -= 1
        return temp

    def get(self, index): # T O(n)  S O(1)
        if index < 0 or index >= self.length:
            return None
        temp = self.head
        if index < self.length/2:
            for _ in range(index):
                temp = temp.next
        else:
            temp = self.tail
            for _ in range(self.length - 1, index, -1):
                temp = temp.prev  
        return temp
    
    def set_value(self, index, value): # T O(n)  S O(1)
        temp = self.get(index)
        if temp:
            temp.value = value
            return True
        return False

    def insert(self, index, value): # T O(n)  S O(1)
        if index < 0 or index > self.length:
            return False
        if index == 0:
            return self.prepend(value)
        if index == self.length:
            return self.append(value)
 
        new_node = Node(value)
        before = self.get(index - 1)
        after = before.next
 
        new_node.prev = before
        new_node.next = after
        before.next = new_node
        after.prev = new_node
        
        self.length += 1   
        return True  

    def remove(self, index): # T O(n)  S O(1)
        if index < 0 or index >= self.length:
            return None
        if index == 0:
            return self.pop_first()
        if index == self.length - 1:
            return self.pop()
 
        temp = self.get(index)
        temp.next.prev = temp.prev
        temp.prev.next = temp.next
        temp.next = None
        temp.prev = None
        self.length -= 1
        return temp

# %%
# Leetcode Practice Q 

# Palindrome check (double linked list)
    def is_palindrome(self):
        start = self.head 
        end = self.tail 
        if self.head is None:
            return True 
        while start.value == end.value:
            start = start.next 
            end =  end.prev 
            
            return True 
        return False

# Reverse (double linked list)
    def reverse(self):
        temp = self.head
        while temp is not None:
            temp.prev, temp.next = temp.next, temp.prev  
            temp = temp.prev
        self.head, self.tail = self.tail, self.head

# Partition list left less, right greater 
    def partition_list(self, x):
        if not self.head:
            return None
    
        dummy1 = Node(0)
        dummy2 = Node(0)
        prev1 = dummy1
        prev2 = dummy2
        current = self.head
    
        while current:
            if current.value < x:
                prev1.next = current
                current.prev = prev1
                prev1 = current
                
            else:
                prev2.next = current
                current.prev = prev2
                prev2 = current
            current = current.next
        
        prev1.next = dummy2.next
        if dummy2.next:
            dummy2.next.prev = prev1
        prev2.next = None
        
        self.head = dummy1.next
        self.head.prev = None
    
# Reverse Between start and end 
def reverse_between(self, start_index, end_index):
        if self.length <= 1 or start_index == end_index:
            return
 
        dummy = Node(0)
        dummy.next = self.head
        self.head.prev = dummy
        prev = dummy
        for _ in range(start_index):
            prev = prev.next
        current = prev.next
 
        for _ in range(end_index - start_index):
            node_to_move = current.next
 
            current.next = node_to_move.next
            if node_to_move.next:
                node_to_move.next.prev = current
 
            node_to_move.next = prev.next
            prev.next.prev = node_to_move
            prev.next = node_to_move
            node_to_move.prev = prev
 
        self.head = dummy.next
        self.head.prev = None

# Swap Pairs 
    def swap_pairs(self):
        dummy_node = Node(0)
        dummy_node.next = self.head
        previous_node = dummy_node
    
        while self.head and self.head.next:
            first_node = self.head
            second_node = self.head.next
    
            previous_node.next = second_node
            first_node.next = second_node.next
            second_node.next = first_node
    
            second_node.prev = previous_node
            first_node.prev = second_node
    
            if first_node.next:
                first_node.next.prev = first_node
    
            self.head = first_node.next
            previous_node = first_node
    
        self.head = dummy_node.next
    
        if self.head:
            self.head.prev = None
