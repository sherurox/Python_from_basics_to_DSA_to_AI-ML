# %%
x= [[1,2,3], [3,4,5], [5,6,7]]

# %%
print(x)
# Out:
# [[1, 2, 3], [3, 4, 5], [5, 6, 7]]

# %%
import numpy as np

# %%
a= np.array(x)

# %%
print(a)
# Out:
# [[1 2 3]
#  [3 4 5]
#  [5 6 7]]

# %%
a
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [5, 6, 7]])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.linspace(-10,10,100)
y= x**2

# %%
plt.plot(x,y)

# %%
import 7_Funtions_and_Methods
# Out:
#   Cell In[46], line 1
#     import 7_Funtions_and_Methods
#             ^
# SyntaxError: invalid decimal literal
