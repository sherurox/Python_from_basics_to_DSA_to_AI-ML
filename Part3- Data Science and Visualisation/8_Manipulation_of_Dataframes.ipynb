# %%
import numpy as np
import pandas as pd
A = [1,2,3,4]
B = [5,6,7,8]
C = [9,0,1,2]
D = [3,4,5,6]
E = [7,8,9,0]
df = pd.DataFrame([A,B,C,D,E], ['a','b','c','d','e'], ['W','X','Y','Z']) #columns X rows
df
# Out:
#    W  X  Y  Z
# a  1  2  3  4
# b  5  6  7  8
# c  9  0  1  2
# d  3  4  5  6
# e  7  8  9  0

# %%
df['P'] = df['Y'] + df['Z']

# %%
df
# Out:
#    W  X  Y  Z   P
# a  1  2  3  4   7
# b  5  6  7  8  15
# c  9  0  1  2   3
# d  3  4  5  6  11
# e  7  8  9  0   9

# %%
df.drop('e') #temproray deletion
# Out:
#    W  X  Y  Z   P
# a  1  2  3  4   7
# b  5  6  7  8  15
# c  9  0  1  2   3
# d  3  4  5  6  11

# %%
df
# Out:
#    W  X  Y  Z   P
# a  1  2  3  4   7
# b  5  6  7  8  15
# c  9  0  1  2   3
# d  3  4  5  6  11
# e  7  8  9  0   9

# %%
df.drop('e', inplace = True) #permenant deletion

# %%
df
# Out:
#    W  X  Y  Z   P
# a  1  2  3  4   7
# b  5  6  7  8  15
# c  9  0  1  2   3
# d  3  4  5  6  11

# %%
df.drop('P', axis =1)
# Out:
#    W  X  Y  Z
# a  1  2  3  4
# b  5  6  7  8
# c  9  0  1  2
# d  3  4  5  6

# %%
#that was to delete column, which needs axis specefication

# %%
df
# Out:
#    W  X  Y  Z   P
# a  1  2  3  4   7
# b  5  6  7  8  15
# c  9  0  1  2   3
# d  3  4  5  6  11

# %%
df.drop('P', axis =1, inplace = True) #permenant deletion

# %%
df
# Out:
#    W  X  Y  Z
# a  1  2  3  4
# b  5  6  7  8
# c  9  0  1  2
# d  3  4  5  6
